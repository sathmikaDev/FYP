# %%
pip install ntscraper
# Out:
# ...
#   Using cached ntscraper-0.3.17-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached ntscraper-0.3.17-py3-none-any.whl (12 kB)
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 645.7 kB/s eta 0:00:06
#    ----- ---------------------------------- 0.5/3.8 MB 645.7 kB/s eta 0:00:06
#    -------- ------------------------------- 0.8/3.8 MB 671.3 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/3.8 MB 689.9 kB/s eta 0:00:05
# ...

# %%
from ntscraper import Nitter

scraper = Nitter(log_level=1, skip_instance_check=False)
# Out:
# Testing instances: 100%|██████████| 14/14 [00:29<00:00,  2.10s/it]

# %%
github_hash_tweets = scraper.get_tweets("github", mode='hashtag', number=10)
# Out:
# 17-Jan-25 20:11:49 - No instance specified, using random instance https://nitter.privacydev.net
# 17-Jan-25 20:11:55 - Current stats for github: 10 tweets, 0 threads...

# %%
print(github_hash_tweets)
# Out:
# {'tweets': [{'link': 'https://twitter.com/Terrasoft_ltd/status/1880135289634713625#m', 'text': 'Where should you start learning #DevOps❔ ▫️Practical experience Projects and Internships: Participate in real projects, internships, or create your own projects on #GitHub Teamwork: Participation in team projects and understanding the principles of #Agile and #Scrum #developers', 'user': {'name': 'Terrasoft Ltd', 'username': '@Terrasoft_ltd', 'profile_id': '1740697261699473408', 'avatar': 'https://pbs.twimg.com/profile_images/1740697261699473408/OFOctMCN_bigger.jpg'}, 'date': 'Jan 17, 2025 · 6:09 AM UTC', 'is-retweet': False, 'is-pinned': False, 'external-link': '', 'replying-to': [], 'quoted-post': {}, 'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 0}, 'pictures': [], 'videos': [], 'gifs': []}, {'link': 'https://twitter.com/AmikDigital/status/1880131422004076582#m', 'text': 'Struggling with GitHub collaboration? 💻 Here are 5 tips for seamless teamwork:  1️⃣ Define roles & c
# ...

# %%
bezos_tweets = scraper.get_tweets("JeffBezos", mode='user')
# Out:
# 17-Jan-25 20:12:37 - No instance specified, using random instance https://nitter.privacydev.net
# 17-Jan-25 20:12:41 - Current stats for JeffBezos: 20 tweets, 0 threads...
# 17-Jan-25 20:12:45 - Current stats for JeffBezos: 40 tweets, 0 threads...
# 17-Jan-25 20:12:49 - Current stats for JeffBezos: 60 tweets, 0 threads...
# 17-Jan-25 20:12:53 - Current stats for JeffBezos: 80 tweets, 0 threads...
# 17-Jan-25 20:12:55 - Empty page on https://nitter.privacydev.net

# %%
print(bezos_tweets)
# Out:
# {'tweets': [{'link': 'https://twitter.com/JeffBezos/status/1880012258698498278#m', 'text': '', 'user': {'name': 'Jeff Bezos', 'username': '@JeffBezos', 'profile_id': '1591558315254890500', 'avatar': 'https://pbs.twimg.com/profile_images/1591558315254890500/ETIHb4Nl_bigger.jpg'}, 'date': 'Jan 16, 2025 · 10:00 PM UTC', 'is-retweet': False, 'is-pinned': False, 'external-link': '', 'replying-to': [], 'quoted-post': {}, 'stats': {'comments': 447, 'retweets': 545, 'quotes': 91, 'likes': 9785}, 'pictures': [], 'videos': ['https://video.twimg.com/amplify_video/1880012144135049217/vid/avc1/854x480/AKPHv0Fbe7j2OIPG.mp4?tag=16'], 'gifs': []}, {'link': 'https://twitter.com/JeffBezos/status/1879976313114779850#m', 'text': '', 'user': {'name': 'Jeff Bezos', 'username': '@JeffBezos', 'profile_id': '1591558315254890500', 'avatar': 'https://pbs.twimg.com/profile_images/1591558315254890500/ETIHb4Nl_bigger.jpg'}, 'date': 'Jan 16, 2025 · 7:37 PM UTC', 'is-retweet': False, 'is-pinned': False, 'external-l
# ...

# %%
terms = ["bitcoin", "BITCOIN", "Bitcoin", "BTC", "btc"]
tweets_data = scraper.get_tweets(terms, mode='term', since='2015-01-09', until='2025-01-09', language='en', number=10)

# %%
tweets_data
# Out:
# [{'tweets': [], 'threads': []},
#  {'tweets': [], 'threads': []},
#  {'tweets': [], 'threads': []},
#  {'tweets': [], 'threads': []},
#  {'tweets': [], 'threads': []}]

# %%
github_hash_tweets = scraper.get_tweets("btc", mode='hashtag', since='2015-01-09', until='2025-01-09')
# Out:
# 17-Jan-25 20:49:06 - No instance specified, using random instance https://nitter.privacydev.net
# 17-Jan-25 20:49:07 - Empty page on https://nitter.privacydev.net

# %%
github_hash_tweets
# Out:
# {'tweets': [{'link': 'https://twitter.com/Terrasoft_ltd/status/1880135289634713625#m',
#    'text': 'Where should you start learning #DevOps❔ ▫️Practical experience Projects and Internships: Participate in real projects, internships, or create your own projects on #GitHub Teamwork: Participation in team projects and understanding the principles of #Agile and #Scrum #developers',
#    'user': {'name': 'Terrasoft Ltd',
#     'username': '@Terrasoft_ltd',
#     'profile_id': '1740697261699473408',
#     'avatar': 'https://pbs.twimg.com/profile_images/1740697261699473408/OFOctMCN_bigger.jpg'},
#    'date': 'Jan 17, 2025 · 6:09 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 0},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/AmikDigital/status/1880131422004076582#m',
# ...

# %%
import csv

# %%
terms = ["bitcoin", "BITCOIN", "Bitcoin", "BTC", "btc"]

# tweets data
tweets_data = scraper.get_tweets("Bitcoin", mode='hashtag', since='2015-01-09', until='2025-01-09', language='en')

with open('scraped_tweets.csv', modw='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    writer.writerow(["username"])
