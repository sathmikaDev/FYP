# %%
import pandas as pd

# %%
# read csvs and merge them
Exogenenous_Variables = pd.read_csv('../Datasetsv2/Exogenous/Exogenous_Variables.csv')
BTC_Data = pd.read_csv('./BTC_USD.csv')
ETH_Data = pd.read_csv('./ETH_USD.csv')
SOL_Data = pd.read_csv('./SOL_USD.csv')
XRP_Data = pd.read_csv('./XRP_USD.csv')

# %%
# remove unwanted dates
start_date = '2015-01-09'
end_date = '2020-04-09'

Exogenenous_Variables = Exogenenous_Variables[~Exogenenous_Variables['Date'].between(start_date, end_date)]

# %%
Exogenenous_Variables.describe()
# Out:
#        Dollar_Index   Gold_Price  Interest_Rate   US_10_Year    VIX_Value
# count   1736.000000  1736.000000    1736.000000  1736.000000  1736.000000
# mean     100.119695  1965.851553       2.548036     2.776871    20.627765
# std        5.911686   263.294307       2.358805     1.391700     6.111166
# min       89.440002  1626.650000       0.040000     0.512000    11.860000
# 25%       93.957499  1793.075000       0.080000     1.454000    15.977500
# 50%      101.924999  1889.532200       2.330000     3.199000    19.535000
# 75%      104.459999  2005.192375       5.080000     4.043500    24.460000
# max      114.110001  2785.872300       5.330000     4.990000    45.410000

# %%
# remove unwanted dates
start_date = '2015-01-09'
end_date = '2020-04-09'

BTC_Data = BTC_Data[~BTC_Data['Date'].between(start_date, end_date)]

# %%
BTC_Data.describe()
# Out:
#            BTC_Price
# count    1736.000000
# mean    38254.076325
# std     20951.122515
# min      6642.109863
# 25%     21532.612793
# 50%     35184.988281
# 75%     53916.755859
# max    106140.601562

# %%
ETH_Data.describe()
# Out:
#          ETH_Price
# count  1736.000000
# mean   2093.838695
# std    1094.459778
# min     153.286896
# 25%    1390.690216
# 50%    1914.151123
# 75%    2971.376770
# max    4812.087402

# %%
# ETH_Data
start_date = '2017-11-09'
end_date = '2020-04-09'

ETH_Data = ETH_Data[~ETH_Data['Date'].between(start_date, end_date)]

# %%
XRP_Data.describe()
# Out:
#            XRP_Price
# count    1736.000000
# mean    38254.076325
# std     20951.122515
# min      6642.109863
# 25%     21532.612793
# 50%     35184.988281
# 75%     53916.755859
# max    106140.601562

# %%
start_date = '2015-01-09'
end_date = '2020-04-09'

XRP_Data = XRP_Data[~XRP_Data['Date'].between(start_date, end_date)]

# %%
# Merge them
Final_Dataset = Exogenenous_Variables.merge(BTC_Data, on="Date", how="outer") \
                        .merge(ETH_Data, on="Date", how="outer") \
                        .merge(SOL_Data, on="Date", how="outer") \
                        .merge(XRP_Data, on="Date", how="outer")

# %%
Final_Dataset.head()
# Out:
#          Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  VIX_Value  \
# 0  2020-04-10     99.519997     1662.50           0.05       0.729      41.67
# 1  2020-04-11     99.519997     1662.50           0.05       0.729      41.67
# 2  2020-04-12     99.519997     1662.50           0.05       0.729      41.67
# 3  2020-04-13     99.349998     1662.50           0.05       0.770      41.17
# 4  2020-04-14     98.889999     1715.85           0.05       0.750      37.76
#
#      BTC_Price   ETH_Price  SOL_Price    XRP_Price
# 0  6865.493164  158.412445   0.951054  6865.493164
# 1  6859.083008  158.216019   0.776819  6859.083008
# 2  6971.091797  161.142426   0.882507  6971.091797
# 3  6845.037598  156.279556   0.777832  6845.037598
# 4  6842.427734  157.596390   0.661925  6842.427734

# %%
# save as a csv
Final_Dataset.to_csv('./Final_Dataset.csv', index=False)

# %% [markdown]
# Feature Engineering - add new features

# %%
Final_DF = pd.read_csv('./Final_Dataset.csv')

# %%
# Reshape the data into long format
Final_DF = Final_DF.melt(
    id_vars=['Date', 'Dollar_Index', 'Gold_Price', 'Interest_Rate', 'US_10_Year', 'VIX_Value'], 
    value_vars=['BTC_Price', 'ETH_Price', 'SOL_Price', 'XRP_Price'],
    var_name='group_id', 
    value_name='target'
)

# Map group_id to a standard format (optional)
Final_DF['group_id'] = Final_DF['group_id'].str.replace('_Price', '')

# Sort by date and group_id
Final_DF = Final_DF.sort_values(by=['Date', 'group_id']).reset_index(drop=True)

# Display the transformed data
print(Final_DF.head())
# Out:
#          Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  VIX_Value  \
# 0  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 1  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 2  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 3  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 4  2020-04-11     99.519997      1662.5           0.05       0.729      41.67
#
#   group_id       target
# 0      BTC  6865.493164
# 1      ETH   158.412445
# 2      SOL     0.951054
# 3      XRP  6865.493164
# 4      BTC  6859.083008

# %%
Final_DF.head()
# Out:
#          Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  VIX_Value  \
# 0  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 1  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 2  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 3  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 4  2020-04-11     99.519997      1662.5           0.05       0.729      41.67
#
#   group_id       target
# 0      BTC  6865.493164
# 1      ETH   158.412445
# 2      SOL     0.951054
# 3      XRP  6865.493164
# 4      BTC  6859.083008

# %%
# add lag features
# Define the number of lags
lag_days = [1, 3, 7]

# Add lag features grouped by 'group_id'
for lag in lag_days:
    Final_DF[f'lag_{lag}'] = Final_DF.groupby('group_id')['target'].shift(lag)

# %%
Final_DF.head()
# Out:
#          Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  VIX_Value  \
# 0  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 1  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 2  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 3  2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 4  2020-04-11     99.519997      1662.5           0.05       0.729      41.67
#
#   group_id       target        lag_1  lag_3  lag_7
# 0      BTC  6865.493164          NaN    NaN    NaN
# 1      ETH   158.412445          NaN    NaN    NaN
# 2      SOL     0.951054          NaN    NaN    NaN
# 3      XRP  6865.493164          NaN    NaN    NaN
# 4      BTC  6859.083008  6865.493164    NaN    NaN

# %%
# Define rolling window sizes
window_sizes = [3, 7]

# Add rolling averages for each group
for window in window_sizes:
    Final_DF[f'ma_{window}'] = Final_DF.groupby('group_id')['target'].rolling(window=window).mean().reset_index(0, drop=True)

# %%
Final_DF.tail()
# Out:
#             Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  \
# 6939  2025-01-08    109.089996   2661.5352           4.33       4.692
# 6940  2025-01-09    109.180000   2669.9489           4.33       4.688
# 6941  2025-01-09    109.180000   2669.9489           4.33       4.688
# 6942  2025-01-09    109.180000   2669.9489           4.33       4.688
# 6943  2025-01-09    109.180000   2669.9489           4.33       4.688
#
#       VIX_Value group_id        target         lag_1          lag_3  \
# 6939      17.70      XRP  95043.523438  96922.703125   98314.960938
# 6940      18.07      BTC  92484.039062  95043.523438  102078.085938
# 6941      18.07      ETH   3219.430664   3326.329346    3688.611328
# 6942      18.07      SOL    185.025284    197.559052     218.723129
# 6943      18.07      XRP  92484.039062  95043.523438  102078.085938
#
#              lag_7          ma_3          ma_7
# 6939  94419.757812  98014.770833  97941.400670
# 6940  96886.875000  94816.755208  97312.424107
# 6941   3451.392578   3309.112467   3501.824149
# 6942    207.767044    194.938197    207.328801
# 6943  96886.875000  94816.755208  97312.424107

# %%
# import necessary libraries
import copy
from pathlib import Path
import warnings

import lightning.pytorch as pl
from lightning.pytorch.callbacks import EarlyStopping, LearningRateMonitor
from lightning.pytorch.loggers import TensorBoardLogger
import numpy as np
import pandas as pd
import torch

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import MAE, SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters
from pytorch_forecasting.data.encoders import NaNLabelEncoder

# %%
# convert date column to datetime format
Final_DF['Date'] = pd.to_datetime(Final_DF['Date'])

# %%
Final_DF.tail()
# Out:
#            Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  \
# 6939 2025-01-08    109.089996   2661.5352           4.33       4.692
# 6940 2025-01-09    109.180000   2669.9489           4.33       4.688
# 6941 2025-01-09    109.180000   2669.9489           4.33       4.688
# 6942 2025-01-09    109.180000   2669.9489           4.33       4.688
# 6943 2025-01-09    109.180000   2669.9489           4.33       4.688
#
#       VIX_Value group_id        target         lag_1          lag_3  \
# 6939      17.70      XRP  95043.523438  96922.703125   98314.960938
# 6940      18.07      BTC  92484.039062  95043.523438  102078.085938
# 6941      18.07      ETH   3219.430664   3326.329346    3688.611328
# 6942      18.07      SOL    185.025284    197.559052     218.723129
# 6943      18.07      XRP  92484.039062  95043.523438  102078.085938
#
#              lag_7          ma_3          ma_7
# 6939  94419.757812  98014.770833  97941.400670
# 6940  96886.875000  94816.755208  97312.424107
# 6941   3451.392578   3309.112467   3501.824149
# 6942    207.767044    194.938197    207.328801
# 6943  96886.875000  94816.755208  97312.424107

# %%
Final_DF["month"] = Final_DF.Date.dt.month.astype(str).astype("category")  # categories have be strings
Final_DF["day_of_week"] = Final_DF.Date.dt.dayofweek.astype(str).astype("category")  # categories have be strings
Final_DF["year"] = Final_DF.Date.dt.year.astype(str).astype("category")  # categories have be strings
Final_DF["day_of_year"] = Final_DF.Date.dt.dayofyear.astype(str).astype("category")  # categories have be strings
Final_DF["quarter"] = Final_DF.Date.dt.quarter.astype(str).astype("category")  # categories have be strings

# %%
Final_DF.head()
# Out:
#         Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  VIX_Value  \
# 0 2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 1 2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 2 2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 3 2020-04-10     99.519997      1662.5           0.05       0.729      41.67
# 4 2020-04-11     99.519997      1662.5           0.05       0.729      41.67
#
#   group_id       target        lag_1  lag_3  lag_7  ma_3  ma_7 month  \
# 0      BTC  6865.493164          NaN    NaN    NaN   NaN   NaN     4
# 1      ETH   158.412445          NaN    NaN    NaN   NaN   NaN     4
# 2      SOL     0.951054          NaN    NaN    NaN   NaN   NaN     4
# 3      XRP  6865.493164          NaN    NaN    NaN   NaN   NaN     4
# 4      BTC  6859.083008  6865.493164    NaN    NaN   NaN   NaN     4
#
#   day_of_week  year day_of_year quarter
# 0           4  2020         101       2
# 1           4  2020         101       2
# 2           4  2020         101       2
# 3           4  2020         101       2
# 4           5  2020         102       2

# %%
Final_DF.dropna(inplace=True)

# %%
Final_DF.head()
# Out:
#          Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  VIX_Value  \
# 28 2020-04-17     99.779999     1693.15           0.05       0.642      38.15
# 29 2020-04-17     99.779999     1693.15           0.05       0.642      38.15
# 30 2020-04-17     99.779999     1693.15           0.05       0.642      38.15
# 31 2020-04-17     99.779999     1693.15           0.05       0.642      38.15
# 32 2020-04-18     99.779999     1693.15           0.05       0.642      38.15
#
#    group_id       target        lag_1        lag_3        lag_7         ma_3  \
# 28      BTC  7096.184570  7116.804199  6842.427734  6865.493164  6951.699544
# 29      ETH   171.638580   172.157379   157.596390   158.412445   165.694285
# 30      SOL     0.660728     0.690816     0.661925     0.951054     0.666065
# 31      XRP  7096.184570  7116.804199  6842.427734  6865.493164  6951.699544
# 32      BTC  7257.665039  7096.184570  6642.109863  6859.083008  7156.884603
#
#            ma_7 month day_of_week  year day_of_year quarter
# 28  6910.391253     4           4  2020         108       2
# 29   161.473892     4           4  2020         108       2
# 30     0.728183     4           4  2020         108       2
# 31  6910.391253     4           4  2020         108       2
# 32  6967.331543     4           5  2020         109       2

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_features = ['Dollar_Index', 'Gold_Price', 'Interest_Rate', 'US_10_Year', 'VIX_Value', 'target']

# Apply scaling per group_id
def scale_group(group):
    group[scaled_features] = scaler.fit_transform(group[scaled_features])  # No reshape needed
    return group

Final_DF = Final_DF.groupby('group_id', group_keys=False).apply(scale_group)
# Out:
# C:\Users\Sathmika\AppData\Local\Temp\ipykernel_22072\4166452389.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   Final_DF = Final_DF.groupby('group_id', group_keys=False).apply(scale_group)

# %%
Final_DF.head()
# Out:
#          Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  VIX_Value  \
# 28 2020-04-17      0.419132    0.057366        0.00189    0.029031   0.783607
# 29 2020-04-17      0.419132    0.057366        0.00189    0.029031   0.783607
# 30 2020-04-17      0.419132    0.057366        0.00189    0.029031   0.783607
# 31 2020-04-17      0.419132    0.057366        0.00189    0.029031   0.783607
# 32 2020-04-18      0.419132    0.057366        0.00189    0.029031   0.783607
#
#    group_id    target        lag_1        lag_3        lag_7         ma_3  \
# 28      BTC  0.002175  7116.804199  6842.427734  6865.493164  6951.699544
# 29      ETH  0.000000   172.157379   157.596390   158.412445   165.694285
# 30      SOL  0.000563     0.690816     0.661925     0.951054     0.666065
# 31      XRP  0.002175  7116.804199  6842.427734  6865.493164  6951.699544
# 32      BTC  0.003802  7096.184570  6642.109863  6859.083008  7156.884603
#
#            ma_7 month day_of_week  year day_of_year quarter
# 28  6910.391253     4           4  2020         108       2
# 29   161.473892     4           4  2020         108       2
# 30     0.728183     4           4  2020         108       2
# 31  6910.391253     4           4  2020         108       2
# 32  6967.331543     4           5  2020         109       2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Time Series Plot
plt.figure(figsize=(12, 8))
plt.plot(Final_DF['Date'], Final_DF['Dollar_Index'], label='Dollar Index')
plt.plot(Final_DF['Date'], Final_DF['Gold_Price'], label='Gold Price')
plt.plot(Final_DF['Date'], Final_DF['Interest_Rate'], label='Interest Rate')
plt.plot(Final_DF['Date'], Final_DF['US_10_Year'], label='US 10 Year')
plt.plot(Final_DF['Date'], Final_DF['VIX_Value'], label='VIX Value')
plt.plot(Final_DF['Date'], Final_DF['target'], label='Target', linestyle='--', color='black')

plt.title('Time Series of Exogenous Variables and Target')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.ravel()

exogenous_vars = ['Dollar_Index', 'Gold_Price', 'Interest_Rate', 'US_10_Year', 'VIX_Value']
for i, var in enumerate(exogenous_vars):
    sns.scatterplot(x=Final_DF[var], y=Final_DF['target'], ax=axes[i])
    axes[i].set_title(f'Scatter Plot: {var} vs Target')
    axes[i].set_xlabel(var)
    axes[i].set_ylabel('Target')

# Remove the last subplot axis (since we only have 5 exogenous variables)
fig.delaxes(axes[5])
plt.tight_layout()
plt.show()

# %%
# Calculate correlation between all numerical variables
correlation_matrix = Final_DF[['Dollar_Index', 'Gold_Price', 'Interest_Rate', 'US_10_Year', 'VIX_Value', 'target']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Exogenous Variables and Target')
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
# Select only the exogenous variables (independent variables)
exogenous_vars = ['Dollar_Index', 'Gold_Price', 'Interest_Rate', 'US_10_Year', 'VIX_Value']

# Add a constant to the exogenous variables for the intercept in the VIF calculation
X = Final_DF[exogenous_vars]
X = add_constant(X)

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Display the VIF data
print(vif_data)
# Out:
#         Variable        VIF
# 0          const  14.033276
# 1   Dollar_Index   6.813425
# 2     Gold_Price   1.635305
# 3  Interest_Rate   8.647135
# 4     US_10_Year  15.108550
# 5      VIX_Value   2.642157

# %%
Final_DF.tail()
# Out:
#            Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  \
# 6939 2025-01-08      0.796514    0.892741       0.810964    0.933452
# 6940 2025-01-09      0.800162    0.899999       0.810964    0.932559
# 6941 2025-01-09      0.800162    0.899999       0.810964    0.932559
# 6942 2025-01-09      0.800162    0.899999       0.810964    0.932559
# 6943 2025-01-09      0.800162    0.899999       0.810964    0.932559
#
#       VIX_Value group_id    target         lag_1          lag_3         lag_7  \
# 6939   0.174069      XRP  0.888202  96922.703125   98314.960938  94419.757812
# 6940   0.185097      BTC  0.862417  95043.523438  102078.085938  96886.875000
# 6941   0.185097      ETH  0.656788   3326.329346    3688.611328   3451.392578
# 6942   0.185097      SOL  0.713995    197.559052     218.723129    207.767044
# 6943   0.185097      XRP  0.862417  95043.523438  102078.085938  96886.875000
#
#               ma_3          ma_7 month day_of_week  year day_of_year quarter  \
# 6939  98014.770833  97941.400670     1           2  2025           8       1
# 6940  94816.755208  97312.424107     1           3  2025           9       1
# 6941   3309.112467   3501.824149     1           3  2025           9       1
# 6942    194.938197    207.328801     1           3  2025           9       1
# 6943  94816.755208  97312.424107     1           3  2025           9       1
#
#       time_idx
# 6939        57
# 6940        57
# 6941        57
# 6942        57
# 6943        57

# %% [markdown]
# ## Building the TFT Model ##

# %%
Final_DF.dtypes
# Out:
# Date             datetime64[ns]
# Dollar_Index            float64
# Gold_Price              float64
# Interest_Rate           float64
# US_10_Year              float64
# VIX_Value               float64
# group_id                 object
# target                  float64
# lag_1                   float64
# lag_3                   float64
# lag_7                   float64
# ma_3                    float64
# ma_7                    float64
# month                  category
# day_of_week            category
# year                   category
# day_of_year            category
# quarter                category
# time_idx                  int32
# dtype: object

# %%
# add time index
Final_DF["time_idx"] = Final_DF["Date"].dt.year * 12 + Final_DF["Date"].dt.month
Final_DF["time_idx"] -= Final_DF["time_idx"].min()

# %%
# Define the training and validation sets
max_prediction_length = 30  # Change based on your prediction horizon (e.g., 30 days)
max_encoder_length = 90  # This defines the history the model will use (e.g., 90 days)
training_cutoff = Final_DF['time_idx'].max() - max_prediction_length

# %%
Final_DF.tail()
# Out:
#            Date  Dollar_Index  Gold_Price  Interest_Rate  US_10_Year  \
# 6939 2025-01-08      0.796514    0.892741       0.810964    0.933452
# 6940 2025-01-09      0.800162    0.899999       0.810964    0.932559
# 6941 2025-01-09      0.800162    0.899999       0.810964    0.932559
# 6942 2025-01-09      0.800162    0.899999       0.810964    0.932559
# 6943 2025-01-09      0.800162    0.899999       0.810964    0.932559
#
#       VIX_Value group_id    target         lag_1          lag_3         lag_7  \
# 6939   0.174069      XRP  0.888202  96922.703125   98314.960938  94419.757812
# 6940   0.185097      BTC  0.862417  95043.523438  102078.085938  96886.875000
# 6941   0.185097      ETH  0.656788   3326.329346    3688.611328   3451.392578
# 6942   0.185097      SOL  0.713995    197.559052     218.723129    207.767044
# 6943   0.185097      XRP  0.862417  95043.523438  102078.085938  96886.875000
#
#               ma_3          ma_7 month day_of_week  year day_of_year quarter  \
# 6939  98014.770833  97941.400670     1           2  2025           8       1
# 6940  94816.755208  97312.424107     1           3  2025           9       1
# 6941   3309.112467   3501.824149     1           3  2025           9       1
# 6942    194.938197    207.328801     1           3  2025           9       1
# 6943  94816.755208  97312.424107     1           3  2025           9       1
#
#       time_idx
# 6939        57
# 6940        57
# 6941        57
# 6942        57
# 6943        57

# %%
train_dataset = TimeSeriesDataSet(
    Final_DF[lambda x: x.time_idx <= training_cutoff],
    time_idx="time_idx",
    target="target",
    group_ids=["group_id"],
    max_encoder_length=max_encoder_length,
    max_prediction_length=max_prediction_length,
    static_reals=[],  # Add any static features like group-level metadata
    time_varying_known_reals=[
        "Dollar_Index",
        "Gold_Price",
        "Interest_Rate",
        "US_10_Year",
        "VIX_Value",
        "month",
        "day_of_week",
        "year",
        "month",
        "day_of_year",
        "quarter"
    ],
    time_varying_unknown_reals=["target", "lag_1", "lag_3", "lag_7", "ma_3", "ma_7"],
    target_normalizer=GroupNormalizer(
        groups=["group_id"], transformation="softplus"
    ),
    allow_missing_timesteps=True,
    categorical_encoders={"time_idx": NaNLabelEncoder(add_nan=True)},
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[448], line 1
# ----> 1 train_dataset = TimeSeriesDataSet(
#       2     Final_DF[lambda x: x.time_idx <= training_cutoff],
#       3     time_idx="time_idx",
#       4     target="target",
#       5     group_ids=["group_id"],
#       6     max_encoder_length=max_encoder_length,
#       7     max_prediction_length=max_prediction_length,
#       8     static_reals=[],  # Add any static features like group-level metadata
#       9     time_varying_known_reals=[
#      10         "Dollar_Index",
#      11         "Gold_Price",
#      12         "Interest_Rate",
#      13         "US_10_Year",
#      14         "VIX_Value",
#      15         "month",
#      16         "day_of_week",
#      17         "year",
#      18         "month",
#      19         "day_of_year",
#      20         "quarter"
#      21     ],
#      22     time_varying_unknown_reals=["target", "lag_1", "lag_3", "lag_7", "ma_3", "ma_7"],
#      23     target_normalizer=GroupNormalizer(
#      24         groups=["group_id"], transformation="softplus"
#      25     ),
#      26     categorical_encoders={"time_idx": NaNLabelEncoder(add_nan=True)}
#      27 )
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\data\timeseries.py:482, in TimeSeriesDataSet.__init__(self, data, time_idx, target, group_ids, weight, max_encoder_length, min_encoder_length, min_prediction_idx, min_prediction_length, max_prediction_length, static_categoricals, static_reals, time_varying_known_categoricals, time_varying_known_reals, time_varying_unknown_categoricals, time_varying_unknown_reals, variable_groups, constant_fill_strategy, allow_missing_timesteps, lags, add_relative_time_idx, add_target_scales, add_encoder_length, target_normalizer, categorical_encoders, scalers, randomize_length, predict_mode)
#     479     assert target not in self.scalers, "Target normalizer is separate and not in scalers."
#     481 # create index
# --> 482 self.index = self._construct_index(data, predict_mode=self.predict_mode)
#     484 # convert to torch tensor for high performance data loading later
#     485 self.data = self._data_to_tensors(data)
#
# File ~\anaconda3\Lib\site-packages\pytorch_forecasting\data\timeseries.py:1238, in TimeSeriesDataSet._construct_index(self, data, predict_mode)
#    1234 # if there are missing timesteps, we cannot say directly what is the last timestep to include
#    1235 # therefore we iterate until it is found
#    1236 if (df_index["time_diff_to_next"] != 1).any():
#    1237     assert (
# -> 1238         self.allow_missing_timesteps
#    1239     ), "Time difference between steps has been idenfied as larger than 1 - set allow_missing_timesteps=True"
#    1241 df_index["index_end"], missing_sequences = _find_end_indices(
#    1242     diffs=df_index.time_diff_to_next.to_numpy(),
#    1243     max_lengths=(max_time - df_index.time).to_numpy() + 1,
#    1244     min_length=min_sequence_length,
#    1245 )
#    1246 # add duplicates but mostly with shorter sequence length for start of timeseries
#    1247 # while the previous steps have ensured that we start a sequence on every time step, the missing_sequences
#    1248 # ensure that there is a sequence that finishes on every timestep
#
# AssertionError: Time difference between steps has been idenfied as larger than 1 - set allow_missing_timesteps=True
